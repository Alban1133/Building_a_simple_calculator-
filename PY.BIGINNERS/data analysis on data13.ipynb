# %%
import pandas as pd
import numpy as np

# %%
#IMPORTING HE DATA USING THE DATAFRAME
df=pd.read_excel("C:\\Users\\dubai\\OneDrive\\Documents\data13.xlsx")

# %%
df
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0   NaN
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0   NaN
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   NaN
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
#HOW TO CLEAN THE DATA USING THE FILLNA METHOD
nw_df=df.fillna(0)
nw_df
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0   0.0
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0   0.0
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
#using the forefill method
#df.fillna(method="ffill")-)this fills the NaN with the digits of the fore row

# %%
#using the interporate method to remove the missing values
df.interpolate()
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0             6      148             72             35        0  33.60
# 1             1       85             66             29        0  26.60
# 2             8      183             64              0        0  27.35
# 3             1       89             66             23       94  28.10
# 4             0      137             40             35      168  43.10
# 5             5      116             74              0        0  37.05
# 6             3       78             50             32       88  31.00
# 7            10      115              0              0        0  35.30
# 8             2      197             70             45      543  30.50
# 9             8      125             96              0        0  34.05
# 10            4      110             92              0        0  37.60
# 11           10      168             74              0        0  38.00
# ...

# %%
#the dropna method delets the rows with the nan or with the missing values
#df.dropna(how="all")--)delets all the rows with the missing values

#you can replace the vlus using rplace method 
#df.replace(["-8888,-6666"],np.NaN)

# %% [markdown]
# # the split apply combine logic

# %%
#HOW TO USE THE GROUPBY FUNCTION

#assume the variable p
p= df.groupby("Glucose")
p

# %%
for Glucose,Glucose_df in p:
    print(Glucose)
    print(Glucose_df)
# Out:
# 78
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 6                     0.248   26        1
# 85
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 1                     0.351   31        0
# 89
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 3                     0.167   21        0
# 100
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 15            7      100              0              0        0  30.0
#
#     DiabetesPedigreeFunction  Age  Outcome
# 15                     0.484   32        1
# 103
# ...

# %%
p.max()
# Out:
#          Pregnancies  BloodPressure  SkinThickness  Insulin   BMI  \
# Glucose
# 78                 3             50             32       88  31.0
# 85                 1             66             29        0  26.6
# 89                 1             66             23       94  28.1
# 100                7              0              0        0  30.0
# 103                1             30             38       83   NaN
# 107                7             74              0        0  29.6
# 110                4             92              0        0  37.6
# 115               10              0              0        0  35.3
# 116                5             74              0        0   NaN
# 118                0             84             47      230  45.8
# 125                8             96              0        0   NaN
# 137                0             40             35      168  43.1
# 139               10             80              0        0  27.1
# ...

# %%
p.min()
# Out:
#          Pregnancies  BloodPressure  SkinThickness  Insulin   BMI  \
# Glucose
# 78                 3             50             32       88  31.0
# 85                 1             66             29        0  26.6
# 89                 1             66             23       94  28.1
# 100                7              0              0        0  30.0
# 103                1             30             38       83   NaN
# 107                7             74              0        0  29.6
# 110                4             92              0        0  37.6
# 115               10              0              0        0  35.3
# 116                5             74              0        0   NaN
# 118                0             84             47      230  45.8
# 125                8             96              0        0   NaN
# 137                0             40             35      168  43.1
# 139               10             80              0        0  27.1
# ...

# %%
# %matplotlib inline
p.plot()
# Out:
# Glucose
# 78     AxesSubplot(0.125,0.11;0.775x0.77)
# 85     AxesSubplot(0.125,0.11;0.775x0.77)
# 89     AxesSubplot(0.125,0.11;0.775x0.77)
# 100    AxesSubplot(0.125,0.11;0.775x0.77)
# 103    AxesSubplot(0.125,0.11;0.775x0.77)
# 107    AxesSubplot(0.125,0.11;0.775x0.77)
# 110    AxesSubplot(0.125,0.11;0.775x0.77)
# 115    AxesSubplot(0.125,0.11;0.775x0.77)
# 116    AxesSubplot(0.125,0.11;0.775x0.77)
# 118    AxesSubplot(0.125,0.11;0.775x0.77)
# 125    AxesSubplot(0.125,0.11;0.775x0.77)
# 137    AxesSubplot(0.125,0.11;0.775x0.77)
# 139    AxesSubplot(0.125,0.11;0.775x0.77)
# 148    AxesSubplot(0.125,0.11;0.775x0.77)
# 166    AxesSubplot(0.125,0.11;0.775x0.77)
# 168    AxesSubplot(0.125,0.11;0.775x0.77)
# 183    AxesSubplot(0.125,0.11;0.775x0.77)
# 189    AxesSubplot(0.125,0.11;0.775x0.77)
# 197    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# # how to concanate the dataframes

# %%
ugand_pop=pd.DataFrame({
    "cities":["kampala","mbarara","masaka"],
    "men_pop":[4000,3000,6000],
    "animal_pop":[1999,400,6000,],
    "women_pop":[200,5000,6000]
    
})
ugand_pop
# Out:
#     cities  men_pop  animal_pop  women_pop
# 0  kampala     4000        1999        200
# 1  mbarara     3000         400       5000
# 2   masaka     6000        6000       6000

# %%
UAE_po-":["dubai","abu_dab","alin"],
    "men_pop":[40000,301,700],
    "animal_pop":[40,100,60,],
    "women_pop":[1000,150,80]
    
})
UAE_pop
# Out:
#     cities  men_pop  animal_pop  women_pop
# 0    dubai    40000          40       1000
# 1  abu_dab      301         100        150
# 2     alin      700          60         80

# %%
#the indeces are not in order
df=pd.concat([ugand_pop,UAE_pop] )
ind
# Out:
#     cities  men_pop  animal_pop  women_pop
# 0  kampala     4000        1999        200
# 1  mbarara     3000         400       5000
# 2   masaka     6000        6000       6000
# 0    dubai    40000          40       1000
# 1  abu_dab      301         100        150
# 2     alin      700          60         80

# %%
#if i want the indices in order
#using the ignore_index
df=pd.concat([ugand_pop,UAE_pop],ignore_index=True)
df
# Out:
#     cities  men_pop  animal_pop  women_pop
# 0  kampala     4000        1999        200
# 1  mbarara     3000         400       5000
# 2   masaka     6000        6000       6000
# 3    dubai    40000          40       1000
# 4  abu_dab      301         100        150
# 5     alin      700          60         80

# %%
#showing the different countries on the first col of the data 
df=pd.concat([ugand_pop,UAE_pop],keys=["uganda","UAE"])
df
# Out:
#            cities  men_pop  animal_pop  women_pop
# uganda 0  kampala     4000        1999        200
#        1  mbarara     3000         400       5000
#        2   masaka     6000        6000       6000
# UAE    0    dubai    40000          40       1000
#        1  abu_dab      301         100        150
#        2     alin      700          60         80

# %%
#what is the use of the keys
#--)it is to access the original data of the df
df.loc["uganda"]
# Out:
#     cities  men_pop  animal_pop  women_pop
# 0  kampala     4000        1999        200
# 1  mbarara     3000         400       5000
# 2   masaka     6000        6000       6000

# %%
#accessing the data for UAE
df.loc["UAE"]
# Out:
#     cities  men_pop  animal_pop  women_pop
# 0    dubai    40000          40       1000
# 1  abu_dab      301         100        150
# 2     alin      700          60         80

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
#x_axis = ['value_1', 'value_2', 'value_3', ...]
#y_axis = ['value_1', 'value_2', 'value_3', ...]

#plt.bar(x_axis, y_axis)#plt.title('title name')
#plt.xlabel('x_axis name')
#plt.ylabel('y_axis name')
#plt.show()


#initializing the axes
y_axis=["uganda"]
#y_axis=["UAE"]



plt.figure(1,figsize=(12,12))
plt.bar(df["y_axis"])
plt.ylabel('uganda')
plt.xlabel()
plt.title('Histogram of df')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'y_axis'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
