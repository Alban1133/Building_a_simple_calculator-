# %%
# How to use print function to display tic-tac-toe
# view 
X = ['1','2','3','4','5','6','7','8','9']
def display_tic_tac_toe():
    print('Tic Tac Toe display')
    count=0
    for i in range(3):
        for j in range(3):
            print('| ',X[count],' |',end='')
            count=count+1
        print('')
        print('-----------------------')
        #print('') # changing the line 

def player_chance_function():
    flagChck=0
    while(flagChck!=1):
        if(i%2!=0):
            ch = int(input('Player 1 Chance(1-9): '))
            sym = 'X'
        else:
            ch = int(input('Player 2 Chance(1-9): '))
            sym = 'O'
        if(ch>=1 and ch<=9):
            if(X[ch-1]!='X' and X[ch-1]!='O'):
                X[ch-1] = sym
                flagChck = 1 # come out of the loop
            else:
                flagChck = 0 # iterate again (while loop)
                print('Place is already taken , Please Select New one ')
        else:
            flagChck = 0
            print('Wrong number Entered, Please Re - Enter :')
            
    
def winningCheckFunction(var):
    win=0#
    if(var==1):
        s = 'X'# check for player 1 winning 
    elif(var==2):
        s='O'# check for player 2 winning
    if(X[0]==s and X[1]==s and X[2]==s):
        win = 1
    elif(X[3]==s and X[4]==s and X[5]==s):
        win = 1
    elif(X[6]==s and X[7]==s and X[8]==s):
        win = 1
    elif(X[0]==s and X[3]==s and X[6]==s):
        win = 1
    elif(X[1]==s and X[4]==s and X[7]==s):
        win = 1
    elif(X[2]==s and X[5]==s and X[8]==s):
        win = 1
    elif(X[0]==s and X[4]==s and X[8]==s):
        win = 1
    elif(X[2]==s and X[4]==s and X[6]==s):
        win = 1
    # analyse the logic 
    if(win==1 and s=='X'):
        return(1)
    elif(win==1 and s=='O'):
        return(2)
    else:
        return(0)
        
    
# main program 

display_tic_tac_toe()
winchk=0
for i in range(1,10,1):

    player_chance_function()# to have legitimate Chance working
    if(i%2!=0):
        winchk = winningCheckFunction(1)# wining condition check
    else:
        winchk = winningCheckFunction(2)# wining condition check
    display_tic_tac_toe()# to update the display and print
    if(winchk==1):
        print('player 1 wins the Game')
        break # break statement will bring the code
        # out of the immediate loop
    elif(winchk==2):
        print('player2 wins the Game')
        break
      
print('Game Ended ')
# Out:
# Tic Tac Toe display
# |  1  ||  2  ||  3  |
# -----------------------
# |  4  ||  5  ||  6  |
# -----------------------
# |  7  ||  8  ||  9  |
# -----------------------
# Player 1 Chance(1-9): 6
# Tic Tac Toe display
# |  1  ||  2  ||  3  |
# -----------------------
# |  4  ||  5  ||  X  |
# -----------------------
# |  7  ||  8  ||  9  |
# -----------------------
# Player 2 Chance(1-9): 2
# Tic Tac Toe display
# |  1  ||  O  ||  3  |
# -----------------------
# |  4  ||  5  ||  X  |
# -----------------------
# |  7  ||  8  ||  9  |
# -----------------------
# Player 1 Chance(1-9): 12
# Wrong number Entered, Please Re - Enter :
